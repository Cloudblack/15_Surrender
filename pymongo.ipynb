# %%
from pymongo import MongoClient
HOST = 'cluster0.zsn5y.mongodb.net'
USER = 'elije465'
PASSWORD = '465684'
DATABASE_NAME = 'myFirstDatabase'
COLLECTION_NAME = 'passengers'
MONGO_URI = f"mongodb+srv://{USER}:{PASSWORD}@{HOST}/{DATABASE_NAME}?retryWrites=true&w=majority&ssl=true&ssl_cert_reqs=CERT_NONE"
client=MongoClient(MONGO_URI)
database=client[DATABASE_NAME]
collection=database[COLLECTION_NAME]
collection.insert_one['hi']
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_77504/2255048228.py:11: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   collection.remove()#콜렉셔닝 계속 쌓여서 초기화시킴
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_77504/2255048228.py in <module>
#       9 database=client[DATABASE_NAME]
#      10 collection=database[COLLECTION_NAME]
# ---> 11 collection.remove()#콜렉셔닝 계속 쌓여서 초기화시킴
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\collection.py in remove(self, spec_or_id, multi, **kwargs)
#    3386         if kwargs:
#    3387             write_concern = WriteConcern(**kwargs)
# -> 3388         return self._delete_retryable(
#    3389             spec_or_id, multi, write_concern, collation=collation)
#    3390
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\collection.py in _delete_retryable(self, criteria, multi, write_concern, op_id, ordered, collation, hint, session)
#    1204                 retryable_write=retryable_write)
#    1205
# -> 1206         return self.__database.client._retryable_write(
#    1207             (write_concern or self.write_concern).acknowledged and not multi,
#    1208             _delete, session)
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1549     def _retryable_write(self, retryable, func, session):
#    1550         """Internal retryable write helper."""
# -> 1551         with self._tmp_session(session) as s:
#    1552             return self._retry_with_session(retryable, func, s, None)
#    1553
#
# D:\conda\envs\n3pj\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1946             return
#    1947
# -> 1948         s = self._ensure_session(session)
#    1949         if s:
#    1950             try:
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1933             # Don't make implicit sessions causally consistent. Applications
#    1934             # should always opt-in.
# -> 1935             return self.__start_session(True, causal_consistency=False)
#    1936         except (ConfigurationError, InvalidOperation):
#    1937             # Sessions not supported, or multiple users authenticated.
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1881
#    1882         # Raises ConfigurationError if sessions are not supported.
# -> 1883         server_session = self._get_server_session()
#    1884         opts = client_session.SessionOptions(**kwargs)
#    1885         return client_session.ClientSession(
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1919     def _get_server_session(self):
#    1920         """Internal: start or resume a _ServerSession."""
# -> 1921         return self._topology.get_server_session()
#    1922
#    1923     def _return_server_session(self, server_session, lock):
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     518             # Sessions are always supported in load balanced mode.
#     519             if not self._settings.load_balanced:
# --> 520                 session_timeout = self._check_session_support()
#     521             else:
#     522                 # Sessions never time out in load balanced mode.
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\topology.py in _check_session_support(self)
#     502                         None)
#     503             elif not self._description.readable_servers:
# --> 504                 self._select_servers_loop(
#     505                     readable_server_selector,
#     506                     self._settings.server_selection_timeout,
#
# D:\conda\envs\n3pj\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     216             # No suitable servers.
#     217             if timeout == 0 or now > end_time:
# --> 218                 raise ServerSelectionTimeoutError(
#     219                     "%s, Timeout: %ss, Topology Description: %r" %
#     220                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: cluster0-shard-00-01.zsn5y.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131),cluster0-shard-00-02.zsn5y.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131),cluster0-shard-00-00.zsn5y.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131), Timeout: 30s, Topology Description: <TopologyDescription id: 615ee598149fe8592909f916, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('cluster0-shard-00-00.zsn5y.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('cluster0-shard-00-00.zsn5y.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131)')>, <ServerDescription ('cluster0-shard-00-01.zsn5y.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('cluster0-shard-00-01.zsn5y.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131)')>, <ServerDescription ('cluster0-shard-00-02.zsn5y.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('cluster0-shard-00-02.zsn5y.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131)')>]>
